# %%
from rdkit import Chem
from rdkit import RDLogger
RDLogger.DisableLog('rdApp.*')
import glob
import numpy as np
from biopandas.pdb import PandasPdb


for sd in glob.glob(f'/groups/cherkasvgrp/share/progressive_docking/hmslati/protacs/linker_smiles/omegas/5EHR_2_docked.sdf'):
    name=sd.split('/')[-1].split('.')[0]
    cname='_'.join(name.split('_')[0:2])
    print(cname)
    for c in glob.glob(f'/groups/cherkasvgrp/share/progressive_docking/hmslati/protacs/radioactive/all_to_conect/{cname}_cnct.idx'):
        distances={}
        infile = open(c, 'r')
        firstLine = infile.readline()
        position=firstLine.split(',')[1]
        position0=firstLine.split(',')[0]
        if position:
            mols = Chem.SDMolSupplier(sd)
            poi=PandasPdb().read_pdb(f'/groups/cherkasvgrp/share/progressive_docking/hmslati/protacs/radioactive/all_to_conect/poi_{cname}_docked_rec.pdb')
            keto_coord = poi.df['HETATM'].iloc[[position0]][['x_coord', 'y_coord', 'z_coord']].to_numpy()
            w = Chem.SDWriter(f'/groups/cherkasvgrp/share/progressive_docking/hmslati/protacs/radioactive/all_to_conect/{name}_short.sdf')
            for idx, m in enumerate(mols):
                pos = m.GetConformer().GetAtomPosition(int(position))
                one=pos.x, pos.y, pos.z
                distance = np.sqrt(np.sum(np.square(keto_coord - one)))
                distances[idx]=distance
            w.write(mols[min(distances, key=distances.get)])
        else:
            pass
# Out:
# 5EHR_2

# %%
from rdkit import Chem
from rdkit import RDLogger
RDLogger.DisableLog('rdApp.*')
import glob
import numpy as np
from biopandas.pdb import PandasPdb

## path to linker docked sdf
for sd in glob.glob(f'/groups/cherkasvgrp/share/progressive_docking/hmslati/protacs/protac_smiles/omegas2/crystals/6HAY*linker.sdf'):
    name=sd.split('/')[-1].split('.')[0]
    cname=name.split('_')[0]
    print(cname)
    ##path to cnct reference
    for c in glob.glob(f'/groups/cherkasvgrp/share/progressive_docking/hmslati/protacs/radioactive/crystals/all_conect/{cname}_cnct.idx'):
        distances={}
        infile = open(c, 'r')
        firstLine = infile.readline()
        position=firstLine.split(',')[1]
        position0=firstLine.split(',')[0]
        if position:
            mols = Chem.SDMolSupplier(sd)
            ##path to pdb POI
            poi=PandasPdb().read_pdb(f'/groups/cherkasvgrp/share/progressive_docking/hmslati/protacs/radioactive/crystals/all_conect/poi_{cname}_docked_rec.pdb')
            keto_coord = poi.df['HETATM'].iloc[[position0]][['x_coord', 'y_coord', 'z_coord']].to_numpy()
            ## path to output dir
            w = Chem.SDWriter(f'/groups/cherkasvgrp/share/progressive_docking/hmslati/protacs/radioactive/crystals/all_conect/{name}_short.sdf')
            for idx, m in enumerate(mols):
                pos = m.GetConformer().GetAtomPosition(int(position))
                one=pos.x, pos.y, pos.z
                distance = np.sqrt(np.sum(np.square(keto_coord - one)))
                distances[idx]=distance
            w.write(mols[min(distances, key=distances.get)])
        else:
            pass
# Out:
# 6HAY

# %%
from rdkit import Chem
from rdkit import RDLogger
RDLogger.DisableLog('rdApp.*')
import glob
import numpy as np
from biopandas.pdb import PandasPdb


for sd in glob.glob(f'./*_linker_docked.sdf'):
    name=sd.split('/')[-1].split('.')[0]
    cname='_'.join(name.split('_')[0:2])
    print(cname)
    for c in glob.glob(f'./conect/{cname}_cnct.idx'):
        distances={}
        infile = open(c, 'r')
        firstLine = infile.readline()
        position=firstLine.split(',')[1]
        position0=firstLine.split(',')[0]
        if position:
            mols = Chem.SDMolSupplier(sd)
            for pdb in glob.glob(f'./*_rec.pdb'):
                poi=PandasPdb().read_pdb(f'{pdb}')
                keto_coord = poi.df['HETATM'].iloc[[position0]][['x_coord', 'y_coord', 'z_coord']].to_numpy()
                w = Chem.SDWriter(f'./{name}_short.sdf')
                for idx, m in enumerate(mols):
                    pos = m.GetConformer().GetAtomPosition(int(position))
                    one=pos.x, pos.y, pos.z
                    distance = np.sqrt(np.sum(np.square(keto_coord - one)))
                    distances[idx]=distance
                w.write(mols[min(distances, key=distances.get)])
        else:
            pass

# %%
from rdkit import Chem
from rdkit import RDLogger
RDLogger.DisableLog('rdApp.*')
import glob
import numpy as np
from biopandas.pdb import PandasPdb
from scipy.spatial import distance

for sd in glob.glob(f'/groups/cherkasvgrp/share/progressive_docking/hmslati/protacs/linker_smiles/omegas/5T8E_16_docked.sdf'):
    name=sd.split('/')[-1].split('.')[0]
    cname='_'.join(name.split('_')[0:2])
    print(cname)
    for c in glob.glob(f'/groups/cherkasvgrp/share/progressive_docking/hmslati/protacs/radioactive/all_to_conect/{cname}_cnct.idx'):
        distances={}
        infile = open(c, 'r')
        firstLine = infile.readline()
        position=firstLine.split(',')[1]
        position0=firstLine.split(',')[0]
        if position:
            mols = Chem.SDMolSupplier(sd)
            poi=PandasPdb().read_pdb(f'/groups/cherkasvgrp/share/progressive_docking/hmslati/protacs/radioactive/all_to_conect/poi_{cname}_docked_rec.pdb')
            keto_coord = poi.df['HETATM'].iloc[[position0]][['x_coord', 'y_coord', 'z_coord']].to_numpy()
            all_coord=poi.df['HETATM'][['x_coord', 'y_coord', 'z_coord']].to_numpy()
            w = Chem.SDWriter(f'/groups/cherkasvgrp/share/progressive_docking/hmslati/protacs/radioactive/all_to_conect/{name}_short.sdf')
            for idx, m in enumerate(mols):
                pos = m.GetConformer().GetAtomPosition(int(position))
                one=pos.x, pos.y, pos.z
                distance1 = np.sqrt(np.sum(np.square(keto_coord - one)))
                distances[idx]=distance1
                temp=[]
                for i in range(m.GetNumAtoms()):
                    temp.append(np.array(m.GetConformer().GetAtomPosition(i)))
                big_ligand=np.stack(temp)

                distance2=np.mean(distance.cdist(all_coord,big_ligand))
                distance3=
                #distances2[idx]=distance2
            #w.write(mols[min(distances, key=distances.get)])
        else:
            pass
