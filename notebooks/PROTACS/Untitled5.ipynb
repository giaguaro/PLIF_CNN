# %%
import prolif
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/MDAnalysis/lib/util.py in <module>
#     216 try:
# --> 217     from ._cutil import unique_int_1d
#     218 except ImportError:
#
# ModuleNotFoundError: No module named 'MDAnalysis.lib._cutil'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-1ea28abbc789> in <module>
# ----> 1 import prolif
#
# ~/.local/lib/python3.6/site-packages/prolif/__init__.py in <module>
# ----> 1 from .molecule import (Molecule,
#       2                        pdbqt_supplier,
#       3                        mol2_supplier,
#       4                        sdf_supplier)
#       5 from .residue import ResidueId
#
# ~/.local/lib/python3.6/site-packages/prolif/molecule.py in <module>
#       5 import copy
#       6 from operator import attrgetter
# ----> 7 import MDAnalysis as mda
#       8 from rdkit import Chem
#       9 from rdkit.Chem.AllChem import AssignBondOrdersFromTemplate
#
# ~/.local/lib/python3.6/site-packages/MDAnalysis/__init__.py in <module>
#     189 )
#     190
# --> 191 from .lib import log
#     192 from .lib.log import start_logging, stop_logging
#     193
#
# ~/.local/lib/python3.6/site-packages/MDAnalysis/lib/__init__.py in <module>
#      32
#      33 from . import log
# ---> 34 from . import transformations
#      35 from . import util
#      36 from . import mdamath
#
# ~/.local/lib/python3.6/site-packages/MDAnalysis/lib/transformations.py in <module>
#     196 from numpy.linalg import norm
#     197
# --> 198 from .mdamath import angle as vecangle
#     199
#     200 def identity_matrix():
#
# ~/.local/lib/python3.6/site-packages/MDAnalysis/lib/mdamath.py in <module>
#      61
#      62 from ..exceptions import NoDataError
# ---> 63 from . import util
#      64 from ._cutil import (make_whole, find_fragments, _sarrus_det_single,
#      65                      _sarrus_det_multiple)
#
# ~/.local/lib/python3.6/site-packages/MDAnalysis/lib/util.py in <module>
#     217     from ._cutil import unique_int_1d
#     218 except ImportError:
# --> 219     raise ImportError("MDAnalysis not installed properly. "
#     220                       "This can happen if your C extensions "
#     221                       "have not been built.")
#
# ImportError: MDAnalysis not installed properly. This can happen if your C extensions have not been built.

# %%
import sys
sys.path.append('/home/hmslati/.conda/envs/py39/lib/python3.7/site-packages/')

# %%
pip install git+https://github.com/chemosim-lab/ProLIF.git
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/chemosim-lab/ProLIF.git
#   Cloning https://github.com/chemosim-lab/ProLIF.git to /tmp/pip-req-build-61jcgwx5
#   Running command git clone -q https://github.com/chemosim-lab/ProLIF.git /tmp/pip-req-build-61jcgwx5
# Collecting mdanalysis@ git+https://github.com/cbouy/mdanalysis.git@prolif#subdirectory=package
#   Cloning https://github.com/cbouy/mdanalysis.git (to revision prolif) to /tmp/pip-install-0m66epng/mdanalysis_4f7b6334342a4203b56730aae7e1b584
#   Running command git clone -q https://github.com/cbouy/mdanalysis.git /tmp/pip-install-0m66epng/mdanalysis_4f7b6334342a4203b56730aae7e1b584
#   Running command git checkout -b prolif --track origin/prolif
#   Switched to a new branch 'prolif'
#   Branch prolif set up to track remote branch prolif from origin.
# Requirement already satisfied: pandas>=1.0.0 in /home/hmslati/.local/lib/python3.6/site-packages (from prolif==0.3.4+7.g51c4206) (1.3.5)
# Requirement already satisfied: numpy>=1.13.3 in /home/hmslati/.local/lib/python3.6/site-packages (from prolif==0.3.4+7.g51c4206) (1.21.5)
# Requirement already satisfied: scipy>=1.3.0 in /home/hmslati/.local/lib/python3.6/site-packages (from prolif==0.3.4+7.g51c4206) (1.7.3)
# Requirement already satisfied: tqdm in /home/hmslati/.local/lib/python3.6/site-packages (from prolif==0.3.4+7.g51c4206) (4.63.0)
# Requirement already satisfied: biopython>=1.71 in /home/hmslati/.local/lib/python3.6/site-packages (from mdanalysis@ git+https://github.com/cbouy/mdanalysis.git@prolif#subdirectory=package->prolif==0.3.4+7.g51c4206) (1.79)
# Requirement already satisfied: networkx>=1.0 in /home/hmslati/.local/lib/python3.6/site-packages (from mdanalysis@ git+https://github.com/cbouy/mdanalysis.git@prolif#subdirectory=package->prolif==0.3.4+7.g51c4206) (2.6.3)
# Requirement already satisfied: GridDataFormats>=0.4.0 in /home/hmslati/.local/lib/python3.6/site-packages (from mdanalysis@ git+https://github.com/cbouy/mdanalysis.git@prolif#subdirectory=package->prolif==0.3.4+7.g51c4206) (0.7.0)
# Requirement already satisfied: mmtf-python>=1.0.0 in /home/hmslati/.local/lib/python3.6/site-packages (from mdanalysis@ git+https://github.com/cbouy/mdanalysis.git@prolif#subdirectory=package->prolif==0.3.4+7.g51c4206) (1.1.2)
# Requirement already satisfied: joblib>=0.12 in /home/hmslati/.local/lib/python3.6/site-packages (from mdanalysis@ git+https://github.com/cbouy/mdanalysis.git@prolif#subdirectory=package->prolif==0.3.4+7.g51c4206) (1.1.0)
# Requirement already satisfied: matplotlib>=1.5.1 in /home/hmslati/.local/lib/python3.6/site-packages (from mdanalysis@ git+https://github.com/cbouy/mdanalysis.git@prolif#subdirectory=package->prolif==0.3.4+7.g51c4206) (3.5.1)
# Requirement already satisfied: threadpoolctl in /home/hmslati/.local/lib/python3.6/site-packages (from mdanalysis@ git+https://github.com/cbouy/mdanalysis.git@prolif#subdirectory=package->prolif==0.3.4+7.g51c4206) (3.1.0)
# Requirement already satisfied: gsd>=1.4.0 in /home/hmslati/.local/lib/python3.6/site-packages (from mdanalysis@ git+https://github.com/cbouy/mdanalysis.git@prolif#subdirectory=package->prolif==0.3.4+7.g51c4206) (2.5.1)
# Requirement already satisfied: mrcfile in /home/hmslati/.local/lib/python3.6/site-packages (from GridDataFormats>=0.4.0->mdanalysis@ git+https://github.com/cbouy/mdanalysis.git@prolif#subdirectory=package->prolif==0.3.4+7.g51c4206) (1.3.0)
# Requirement already satisfied: six in /home/hmslati/.local/lib/python3.6/site-packages (from GridDataFormats>=0.4.0->mdanalysis@ git+https://github.com/cbouy/mdanalysis.git@prolif#subdirectory=package->prolif==0.3.4+7.g51c4206) (1.16.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/hmslati/.local/lib/python3.6/site-packages (from matplotlib>=1.5.1->mdanalysis@ git+https://github.com/cbouy/mdanalysis.git@prolif#subdirectory=package->prolif==0.3.4+7.g51c4206) (4.31.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/hmslati/.local/lib/python3.6/site-packages (from matplotlib>=1.5.1->mdanalysis@ git+https://github.com/cbouy/mdanalysis.git@prolif#subdirectory=package->prolif==0.3.4+7.g51c4206) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in /home/hmslati/.local/lib/python3.6/site-packages (from matplotlib>=1.5.1->mdanalysis@ git+https://github.com/cbouy/mdanalysis.git@prolif#subdirectory=package->prolif==0.3.4+7.g51c4206) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/hmslati/.local/lib/python3.6/site-packages (from matplotlib>=1.5.1->mdanalysis@ git+https://github.com/cbouy/mdanalysis.git@prolif#subdirectory=package->prolif==0.3.4+7.g51c4206) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/hmslati/.local/lib/python3.6/site-packages (from matplotlib>=1.5.1->mdanalysis@ git+https://github.com/cbouy/mdanalysis.git@prolif#subdirectory=package->prolif==0.3.4+7.g51c4206) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/hmslati/.local/lib/python3.6/site-packages (from matplotlib>=1.5.1->mdanalysis@ git+https://github.com/cbouy/mdanalysis.git@prolif#subdirectory=package->prolif==0.3.4+7.g51c4206) (1.4.0)
# Requirement already satisfied: cycler>=0.10 in /home/hmslati/.local/lib/python3.6/site-packages (from matplotlib>=1.5.1->mdanalysis@ git+https://github.com/cbouy/mdanalysis.git@prolif#subdirectory=package->prolif==0.3.4+7.g51c4206) (0.11.0)
# Requirement already satisfied: typing-extensions in /home/hmslati/.local/lib/python3.6/site-packages (from kiwisolver>=1.0.1->matplotlib>=1.5.1->mdanalysis@ git+https://github.com/cbouy/mdanalysis.git@prolif#subdirectory=package->prolif==0.3.4+7.g51c4206) (4.1.1)
# Requirement already satisfied: msgpack>=0.5.6 in /home/hmslati/.local/lib/python3.6/site-packages (from mmtf-python>=1.0.0->mdanalysis@ git+https://github.com/cbouy/mdanalysis.git@prolif#subdirectory=package->prolif==0.3.4+7.g51c4206) (1.0.3)
# Requirement already satisfied: pytz>=2017.3 in /home/hmslati/.local/lib/python3.6/site-packages (from pandas>=1.0.0->prolif==0.3.4+7.g51c4206) (2021.3)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.6/site-packages (from tqdm->prolif==0.3.4+7.g51c4206) (5.1.2)
# Requirement already satisfied: zipp>=0.4 in /usr/local/lib/python3.6/site-packages (from importlib-resources->tqdm->prolif==0.3.4+7.g51c4206) (3.4.1)
# Building wheels for collected packages: mdanalysis
#   Building wheel for mdanalysis (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /groups/cherkasvgrp/share/progressive_docking/pd_python/tensorflow_gpu/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-0m66epng/mdanalysis_4f7b6334342a4203b56730aae7e1b584/package/setup.py'"'"'; __file__='"'"'/tmp/pip-install-0m66epng/mdanalysis_4f7b6334342a4203b56730aae7e1b584/package/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-t17oj25u
#        cwd: /tmp/pip-install-0m66epng/mdanalysis_4f7b6334342a4203b56730aae7e1b584/package
#   Complete output (240 lines):
#   Attempting to autodetect OpenMP support... Compiler supports OpenMP
#   Will attempt to use Cython.
#   Compiling MDAnalysis/lib/formats/libdcd.pyx because it changed.
#   Compiling MDAnalysis/lib/c_distances.pyx because it changed.
#   Compiling MDAnalysis/lib/c_distances_openmp.pyx because it changed.
#   Compiling MDAnalysis/lib/qcprot.pyx because it changed.
#   Compiling MDAnalysis/lib/formats/libmdaxdr.pyx because it changed.
#   Compiling MDAnalysis/lib/formats/cython_util.pyx because it changed.
#   Compiling MDAnalysis/analysis/encore/cutils.pyx because it changed.
#   Compiling MDAnalysis/analysis/encore/clustering/affinityprop.pyx because it changed.
#   Compiling MDAnalysis/analysis/encore/dimensionality_reduction/stochasticproxembed.pyx because it changed.
#   Compiling MDAnalysis/lib/_cutil.pyx because it changed.
#   Compiling MDAnalysis/lib/_augment.pyx because it changed.
#   Compiling MDAnalysis/lib/nsgrid.pyx because it changed.
#   [ 1/12] Cythonizing MDAnalysis/analysis/encore/clustering/affinityprop.pyx
#   [ 2/12] Cythonizing MDAnalysis/analysis/encore/cutils.pyx
#   [ 3/12] Cythonizing MDAnalysis/analysis/encore/dimensionality_reduction/stochasticproxembed.pyx
#   [ 4/12] Cythonizing MDAnalysis/lib/_augment.pyx
#   [ 5/12] Cythonizing MDAnalysis/lib/_cutil.pyx
#   [ 6/12] Cythonizing MDAnalysis/lib/c_distances.pyx
#   [ 7/12] Cythonizing MDAnalysis/lib/c_distances_openmp.pyx
#   [ 8/12] Cythonizing MDAnalysis/lib/formats/cython_util.pyx
#   [ 9/12] Cythonizing MDAnalysis/lib/formats/libdcd.pyx
#   [10/12] Cythonizing MDAnalysis/lib/formats/libmdaxdr.pyx
#   [11/12] Cythonizing MDAnalysis/lib/nsgrid.pyx
#   [12/12] Cythonizing MDAnalysis/lib/qcprot.pyx
#   /home/hmslati/.local/lib/python3.6/site-packages/setuptools/dist.py:493: UserWarning: Normalizing '2.0.0-dev0' to '2.0.0.dev0'
#     warnings.warn(tmpl.format(**locals()))
#   running bdist_wheel
#   The [wheel] section is deprecated. Use [bdist_wheel] instead.
#   running build
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-3.6
#   creating build/lib.linux-x86_64-3.6/MDAnalysis
#   copying MDAnalysis/__init__.py -> build/lib.linux-x86_64-3.6/MDAnalysis
#   copying MDAnalysis/due.py -> build/lib.linux-x86_64-3.6/MDAnalysis
#   copying MDAnalysis/exceptions.py -> build/lib.linux-x86_64-3.6/MDAnalysis
#   copying MDAnalysis/units.py -> build/lib.linux-x86_64-3.6/MDAnalysis
#   copying MDAnalysis/version.py -> build/lib.linux-x86_64-3.6/MDAnalysis
#   copying MDAnalysis/authors.py -> build/lib.linux-x86_64-3.6/MDAnalysis
#   creating build/lib.linux-x86_64-3.6/MDAnalysis/analysis
#   copying MDAnalysis/analysis/__init__.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis
#   copying MDAnalysis/analysis/align.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis
#   copying MDAnalysis/analysis/base.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis
#   copying MDAnalysis/analysis/bat.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis
#   copying MDAnalysis/analysis/contacts.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis
#   copying MDAnalysis/analysis/density.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis
#   copying MDAnalysis/analysis/diffusionmap.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis
#   copying MDAnalysis/analysis/dihedrals.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis
#   copying MDAnalysis/analysis/distances.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis
#   copying MDAnalysis/analysis/gnm.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis
#   copying MDAnalysis/analysis/helix_analysis.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis
#   copying MDAnalysis/analysis/leaflet.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis
#   copying MDAnalysis/analysis/lineardensity.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis
#   copying MDAnalysis/analysis/msd.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis
#   copying MDAnalysis/analysis/nuclinfo.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis
#   copying MDAnalysis/analysis/pca.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis
#   copying MDAnalysis/analysis/polymer.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis
#   copying MDAnalysis/analysis/psa.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis
#   copying MDAnalysis/analysis/rdf.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis
#   copying MDAnalysis/analysis/rms.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis
#   copying MDAnalysis/analysis/waterdynamics.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis
#   creating build/lib.linux-x86_64-3.6/MDAnalysis/auxiliary
#   copying MDAnalysis/auxiliary/XVG.py -> build/lib.linux-x86_64-3.6/MDAnalysis/auxiliary
#   copying MDAnalysis/auxiliary/__init__.py -> build/lib.linux-x86_64-3.6/MDAnalysis/auxiliary
#   copying MDAnalysis/auxiliary/base.py -> build/lib.linux-x86_64-3.6/MDAnalysis/auxiliary
#   copying MDAnalysis/auxiliary/core.py -> build/lib.linux-x86_64-3.6/MDAnalysis/auxiliary
#   creating build/lib.linux-x86_64-3.6/MDAnalysis/converters
#   copying MDAnalysis/converters/OpenMM.py -> build/lib.linux-x86_64-3.6/MDAnalysis/converters
#   copying MDAnalysis/converters/OpenMMParser.py -> build/lib.linux-x86_64-3.6/MDAnalysis/converters
#   copying MDAnalysis/converters/ParmEd.py -> build/lib.linux-x86_64-3.6/MDAnalysis/converters
#   copying MDAnalysis/converters/ParmEdParser.py -> build/lib.linux-x86_64-3.6/MDAnalysis/converters
#   copying MDAnalysis/converters/RDKitParser.py -> build/lib.linux-x86_64-3.6/MDAnalysis/converters
#   copying MDAnalysis/converters/__init__.py -> build/lib.linux-x86_64-3.6/MDAnalysis/converters
#   copying MDAnalysis/converters/RDKit.py -> build/lib.linux-x86_64-3.6/MDAnalysis/converters
#   creating build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/CRD.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/DCD.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/DLPoly.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/DMS.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/FHIAIMS.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/GMS.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/GRO.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/GSD.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/H5MD.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/INPCRD.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/LAMMPS.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/MMTF.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/MOL2.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/NAMDBIN.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/PDB.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/PDBQT.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/PQR.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/ParmEd.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/TRJ.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/TRR.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/TRZ.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/TXYZ.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/XDR.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/XTC.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/XYZ.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/__init__.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/base.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/chain.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/chemfiles.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/core.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/memory.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   copying MDAnalysis/coordinates/null.py -> build/lib.linux-x86_64-3.6/MDAnalysis/coordinates
#   creating build/lib.linux-x86_64-3.6/MDAnalysis/core
#   copying MDAnalysis/core/__init__.py -> build/lib.linux-x86_64-3.6/MDAnalysis/core
#   copying MDAnalysis/core/_get_readers.py -> build/lib.linux-x86_64-3.6/MDAnalysis/core
#   copying MDAnalysis/core/accessors.py -> build/lib.linux-x86_64-3.6/MDAnalysis/core
#   copying MDAnalysis/core/groups.py -> build/lib.linux-x86_64-3.6/MDAnalysis/core
#   copying MDAnalysis/core/topology.py -> build/lib.linux-x86_64-3.6/MDAnalysis/core
#   copying MDAnalysis/core/topologyattrs.py -> build/lib.linux-x86_64-3.6/MDAnalysis/core
#   copying MDAnalysis/core/topologyobjects.py -> build/lib.linux-x86_64-3.6/MDAnalysis/core
#   copying MDAnalysis/core/universe.py -> build/lib.linux-x86_64-3.6/MDAnalysis/core
#   copying MDAnalysis/core/selection.py -> build/lib.linux-x86_64-3.6/MDAnalysis/core
#   creating build/lib.linux-x86_64-3.6/MDAnalysis/lib
#   copying MDAnalysis/lib/NeighborSearch.py -> build/lib.linux-x86_64-3.6/MDAnalysis/lib
#   copying MDAnalysis/lib/__init__.py -> build/lib.linux-x86_64-3.6/MDAnalysis/lib
#   copying MDAnalysis/lib/correlations.py -> build/lib.linux-x86_64-3.6/MDAnalysis/lib
#   copying MDAnalysis/lib/distances.py -> build/lib.linux-x86_64-3.6/MDAnalysis/lib
#   copying MDAnalysis/lib/log.py -> build/lib.linux-x86_64-3.6/MDAnalysis/lib
#   copying MDAnalysis/lib/mdamath.py -> build/lib.linux-x86_64-3.6/MDAnalysis/lib
#   copying MDAnalysis/lib/picklable_file_io.py -> build/lib.linux-x86_64-3.6/MDAnalysis/lib
#   copying MDAnalysis/lib/pkdtree.py -> build/lib.linux-x86_64-3.6/MDAnalysis/lib
#   copying MDAnalysis/lib/transformations.py -> build/lib.linux-x86_64-3.6/MDAnalysis/lib
#   copying MDAnalysis/lib/util.py -> build/lib.linux-x86_64-3.6/MDAnalysis/lib
#   creating build/lib.linux-x86_64-3.6/MDAnalysis/selections
#   copying MDAnalysis/selections/__init__.py -> build/lib.linux-x86_64-3.6/MDAnalysis/selections
#   copying MDAnalysis/selections/base.py -> build/lib.linux-x86_64-3.6/MDAnalysis/selections
#   copying MDAnalysis/selections/charmm.py -> build/lib.linux-x86_64-3.6/MDAnalysis/selections
#   copying MDAnalysis/selections/gromacs.py -> build/lib.linux-x86_64-3.6/MDAnalysis/selections
#   copying MDAnalysis/selections/jmol.py -> build/lib.linux-x86_64-3.6/MDAnalysis/selections
#   copying MDAnalysis/selections/pymol.py -> build/lib.linux-x86_64-3.6/MDAnalysis/selections
#   copying MDAnalysis/selections/vmd.py -> build/lib.linux-x86_64-3.6/MDAnalysis/selections
#   creating build/lib.linux-x86_64-3.6/MDAnalysis/tests
#   copying MDAnalysis/tests/__init__.py -> build/lib.linux-x86_64-3.6/MDAnalysis/tests
#   copying MDAnalysis/tests/datafiles.py -> build/lib.linux-x86_64-3.6/MDAnalysis/tests
#   creating build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   copying MDAnalysis/topology/CRDParser.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   copying MDAnalysis/topology/DLPolyParser.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   copying MDAnalysis/topology/DMSParser.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   copying MDAnalysis/topology/ExtendedPDBParser.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   copying MDAnalysis/topology/FHIAIMSParser.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   copying MDAnalysis/topology/GMSParser.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   copying MDAnalysis/topology/GROParser.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   copying MDAnalysis/topology/GSDParser.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   copying MDAnalysis/topology/HoomdXMLParser.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   copying MDAnalysis/topology/ITPParser.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   copying MDAnalysis/topology/LAMMPSParser.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   copying MDAnalysis/topology/MMTFParser.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   copying MDAnalysis/topology/MOL2Parser.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   copying MDAnalysis/topology/MinimalParser.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   copying MDAnalysis/topology/PDBParser.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   copying MDAnalysis/topology/PDBQTParser.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   copying MDAnalysis/topology/PQRParser.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   copying MDAnalysis/topology/PSFParser.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   copying MDAnalysis/topology/ParmEdParser.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   copying MDAnalysis/topology/TOPParser.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   copying MDAnalysis/topology/TPRParser.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   copying MDAnalysis/topology/TXYZParser.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   copying MDAnalysis/topology/XYZParser.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   copying MDAnalysis/topology/__init__.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   copying MDAnalysis/topology/base.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   copying MDAnalysis/topology/core.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   copying MDAnalysis/topology/tables.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   copying MDAnalysis/topology/guessers.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology
#   creating build/lib.linux-x86_64-3.6/MDAnalysis/transformations
#   copying MDAnalysis/transformations/__init__.py -> build/lib.linux-x86_64-3.6/MDAnalysis/transformations
#   copying MDAnalysis/transformations/base.py -> build/lib.linux-x86_64-3.6/MDAnalysis/transformations
#   copying MDAnalysis/transformations/boxdimensions.py -> build/lib.linux-x86_64-3.6/MDAnalysis/transformations
#   copying MDAnalysis/transformations/fit.py -> build/lib.linux-x86_64-3.6/MDAnalysis/transformations
#   copying MDAnalysis/transformations/positionaveraging.py -> build/lib.linux-x86_64-3.6/MDAnalysis/transformations
#   copying MDAnalysis/transformations/rotate.py -> build/lib.linux-x86_64-3.6/MDAnalysis/transformations
#   copying MDAnalysis/transformations/translate.py -> build/lib.linux-x86_64-3.6/MDAnalysis/transformations
#   copying MDAnalysis/transformations/wrap.py -> build/lib.linux-x86_64-3.6/MDAnalysis/transformations
#   creating build/lib.linux-x86_64-3.6/MDAnalysis/visualization
#   copying MDAnalysis/visualization/__init__.py -> build/lib.linux-x86_64-3.6/MDAnalysis/visualization
#   copying MDAnalysis/visualization/streamlines.py -> build/lib.linux-x86_64-3.6/MDAnalysis/visualization
#   copying MDAnalysis/visualization/streamlines_3D.py -> build/lib.linux-x86_64-3.6/MDAnalysis/visualization
#   creating build/lib.linux-x86_64-3.6/MDAnalysis/analysis/data
#   copying MDAnalysis/analysis/data/__init__.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/data
#   copying MDAnalysis/analysis/data/filenames.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/data
#   creating build/lib.linux-x86_64-3.6/MDAnalysis/analysis/encore
#   copying MDAnalysis/analysis/encore/__init__.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/encore
#   copying MDAnalysis/analysis/encore/bootstrap.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/encore
#   copying MDAnalysis/analysis/encore/confdistmatrix.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/encore
#   copying MDAnalysis/analysis/encore/covariance.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/encore
#   copying MDAnalysis/analysis/encore/similarity.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/encore
#   copying MDAnalysis/analysis/encore/utils.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/encore
#   creating build/lib.linux-x86_64-3.6/MDAnalysis/analysis/hbonds
#   copying MDAnalysis/analysis/hbonds/__init__.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/hbonds
#   copying MDAnalysis/analysis/hbonds/hbond_autocorrel.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/hbonds
#   creating build/lib.linux-x86_64-3.6/MDAnalysis/analysis/hole2
#   copying MDAnalysis/analysis/hole2/__init__.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/hole2
#   copying MDAnalysis/analysis/hole2/hole.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/hole2
#   copying MDAnalysis/analysis/hole2/templates.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/hole2
#   copying MDAnalysis/analysis/hole2/utils.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/hole2
#   creating build/lib.linux-x86_64-3.6/MDAnalysis/analysis/hydrogenbonds
#   copying MDAnalysis/analysis/hydrogenbonds/__init__.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/hydrogenbonds
#   copying MDAnalysis/analysis/hydrogenbonds/hbond_analysis.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/hydrogenbonds
#   copying MDAnalysis/analysis/hydrogenbonds/hbond_autocorrel.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/hydrogenbonds
#   copying MDAnalysis/analysis/hydrogenbonds/wbridge_analysis.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/hydrogenbonds
#   creating build/lib.linux-x86_64-3.6/MDAnalysis/analysis/legacy
#   copying MDAnalysis/analysis/legacy/__init__.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/legacy
#   copying MDAnalysis/analysis/legacy/x3dna.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/legacy
#   creating build/lib.linux-x86_64-3.6/MDAnalysis/analysis/encore/clustering
#   copying MDAnalysis/analysis/encore/clustering/ClusterCollection.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/encore/clustering
#   copying MDAnalysis/analysis/encore/clustering/ClusteringMethod.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/encore/clustering
#   copying MDAnalysis/analysis/encore/clustering/__init__.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/encore/clustering
#   copying MDAnalysis/analysis/encore/clustering/cluster.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/encore/clustering
#   creating build/lib.linux-x86_64-3.6/MDAnalysis/analysis/encore/dimensionality_reduction
#   copying MDAnalysis/analysis/encore/dimensionality_reduction/DimensionalityReductionMethod.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/encore/dimensionality_reduction
#   copying MDAnalysis/analysis/encore/dimensionality_reduction/__init__.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/encore/dimensionality_reduction
#   copying MDAnalysis/analysis/encore/dimensionality_reduction/reduce_dimensionality.py -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/encore/dimensionality_reduction
#   creating build/lib.linux-x86_64-3.6/MDAnalysis/lib/formats
#   copying MDAnalysis/lib/formats/__init__.py -> build/lib.linux-x86_64-3.6/MDAnalysis/lib/formats
#   creating build/lib.linux-x86_64-3.6/MDAnalysis/topology/tpr
#   copying MDAnalysis/topology/tpr/__init__.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology/tpr
#   copying MDAnalysis/topology/tpr/obj.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology/tpr
#   copying MDAnalysis/topology/tpr/setting.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology/tpr
#   copying MDAnalysis/topology/tpr/utils.py -> build/lib.linux-x86_64-3.6/MDAnalysis/topology/tpr
#   copying MDAnalysis/analysis/data/janin_ref_data.npy -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/data
#   copying MDAnalysis/analysis/data/rama_ref_data.npy -> build/lib.linux-x86_64-3.6/MDAnalysis/analysis/data
#   running build_ext
#   building 'MDAnalysis.lib.formats.libdcd' extension
#   creating build/temp.linux-x86_64-3.6
#   creating build/temp.linux-x86_64-3.6/MDAnalysis
#   creating build/temp.linux-x86_64-3.6/MDAnalysis/lib
#   creating build/temp.linux-x86_64-3.6/MDAnalysis/lib/formats
#   /home/hmslati/.conda/envs/py39/bin/x86_64-conda-linux-gnu-cc -DNDEBUG -O2 -g -pipe -Wall -Wp,-D_FORTIFY_SOURCE=2 -fexceptions -fstack-protector-strong --param=ssp-buffer-size=4 -grecord-gcc-switches -m64 -mtune=generic -D_GNU_SOURCE -fPIC -fwrapv -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/hmslati/.conda/envs/py39/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/hmslati/.conda/envs/py39/include -fPIC -I/tmp/pip-install-0m66epng/mdanalysis_4f7b6334342a4203b56730aae7e1b584/package/MDAnalysis/lib/formats -I/home/hmslati/.local/lib/python3.6/site-packages/numpy/core/include -I/tmp/pip-install-0m66epng/mdanalysis_4f7b6334342a4203b56730aae7e1b584/package/MDAnalysis/lib/formats/include -I/usr/include/python3.6m -c MDAnalysis/lib/formats/libdcd.c -o build/temp.linux-x86_64-3.6/MDAnalysis/lib/formats/libdcd.o -std=c99 -ffast-math -O3 -funroll-loops -fsigned-zeros
#   cc1: warning: '-fassociative-math' disabled; other options take precedence
#   MDAnalysis/lib/formats/libdcd.c:36:10: fatal error: Python.h: No such file or directory
#      36 | #include "Python.h"
#         |          ^~~~~~~~~~
#   compilation terminated.
#   error: command '/home/hmslati/.conda/envs/py39/bin/x86_64-conda-linux-gnu-cc' failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for mdanalysis
#   Running setup.py clean for mdanalysis
#   ERROR: Command errored out with exit status 1:
#    command: /groups/cherkasvgrp/share/progressive_docking/pd_python/tensorflow_gpu/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-0m66epng/mdanalysis_4f7b6334342a4203b56730aae7e1b584/package/setup.py'"'"'; __file__='"'"'/tmp/pip-install-0m66epng/mdanalysis_4f7b6334342a4203b56730aae7e1b584/package/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' clean --all
#        cwd: /tmp/pip-install-0m66epng/mdanalysis_4f7b6334342a4203b56730aae7e1b584
#   Complete output (15 lines):
#   Attempting to autodetect OpenMP support... Compiler supports OpenMP
#   Will attempt to use Cython.
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/tmp/pip-install-0m66epng/mdanalysis_4f7b6334342a4203b56730aae7e1b584/package/setup.py", line 588, in <module>
#       exts, cythonfiles = extensions(config)
#     File "/tmp/pip-install-0m66epng/mdanalysis_4f7b6334342a4203b56730aae7e1b584/package/setup.py", line 451, in extensions
#       'language_level': '3'},
#     File "/home/hmslati/.local/lib/python3.6/site-packages/Cython/Build/Dependencies.py", line 977, in cythonize
#       aliases=aliases)
#     File "/home/hmslati/.local/lib/python3.6/site-packages/Cython/Build/Dependencies.py", line 816, in create_extension_list
#       for file in nonempty(sorted(extended_iglob(filepattern)), "'%s' doesn't match any files" % filepattern):
#     File "/home/hmslati/.local/lib/python3.6/site-packages/Cython/Build/Dependencies.py", line 114, in nonempty
#       raise ValueError(error_msg)
#   ValueError: 'MDAnalysis/lib/formats/libdcd.pyx' doesn't match any files
#   ----------------------------------------
#   ERROR: Failed cleaning build dir for mdanalysis
# Failed to build mdanalysis
# Installing collected packages: mdanalysis
#   Attempting uninstall: mdanalysis
#     Found existing installation: MDAnalysis 2.1.0
#     Uninstalling MDAnalysis-2.1.0:
#       Successfully uninstalled MDAnalysis-2.1.0
#     Running setup.py install for mdanalysis ... error
#     ERROR: Command errored out with exit status 1:
#      command: /groups/cherkasvgrp/share/progressive_docking/pd_python/tensorflow_gpu/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-0m66epng/mdanalysis_4f7b6334342a4203b56730aae7e1b584/package/setup.py'"'"'; __file__='"'"'/tmp/pip-install-0m66epng/mdanalysis_4f7b6334342a4203b56730aae7e1b584/package/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-uc6j8err/install-record.txt --single-version-externally-managed --user --prefix= --compile --install-headers /home/hmslati/.local/include/python3.6m/mdanalysis
#          cwd: /tmp/pip-install-0m66epng/mdanalysis_4f7b6334342a4203b56730aae7e1b584/package
#     Complete output (19 lines):
#     Attempting to autodetect OpenMP support... Compiler supports OpenMP
#     Will attempt to use Cython.
#     /home/hmslati/.local/lib/python3.6/site-packages/setuptools/dist.py:493: UserWarning: Normalizing '2.0.0-dev0' to '2.0.0.dev0'
#       warnings.warn(tmpl.format(**locals()))
#     running install
#     /home/hmslati/.local/lib/python3.6/site-packages/setuptools/command/install.py:37: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       setuptools.SetuptoolsDeprecationWarning,
#     running build
#     running build_py
#     copying MDAnalysis/authors.py -> build/lib.linux-x86_64-3.6/MDAnalysis
#     running build_ext
#     building 'MDAnalysis.lib.formats.libdcd' extension
#     /home/hmslati/.conda/envs/py39/bin/x86_64-conda-linux-gnu-cc -DNDEBUG -O2 -g -pipe -Wall -Wp,-D_FORTIFY_SOURCE=2 -fexceptions -fstack-protector-strong --param=ssp-buffer-size=4 -grecord-gcc-switches -m64 -mtune=generic -D_GNU_SOURCE -fPIC -fwrapv -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/hmslati/.conda/envs/py39/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/hmslati/.conda/envs/py39/include -fPIC -I/tmp/pip-install-0m66epng/mdanalysis_4f7b6334342a4203b56730aae7e1b584/package/MDAnalysis/lib/formats -I/home/hmslati/.local/lib/python3.6/site-packages/numpy/core/include -I/tmp/pip-install-0m66epng/mdanalysis_4f7b6334342a4203b56730aae7e1b584/package/MDAnalysis/lib/formats/include -I/usr/include/python3.6m -c MDAnalysis/lib/formats/libdcd.c -o build/temp.linux-x86_64-3.6/MDAnalysis/lib/formats/libdcd.o -std=c99 -ffast-math -O3 -funroll-loops -fsigned-zeros
#     cc1: warning: '-fassociative-math' disabled; other options take precedence
#     MDAnalysis/lib/formats/libdcd.c:36:10: fatal error: Python.h: No such file or directory
#        36 | #include "Python.h"
#           |          ^~~~~~~~~~
#     compilation terminated.
#     error: command '/home/hmslati/.conda/envs/py39/bin/x86_64-conda-linux-gnu-cc' failed with exit status 1
#     ----------------------------------------
#   Rolling back uninstall of MDAnalysis
#   Moving to /home/hmslati/.local/lib/python3.6/site-packages/MDAnalysis-2.1.0.dist-info/
#    from /home/hmslati/.local/lib/python3.6/site-packages/~DAnalysis-2.1.0.dist-info
#   Moving to /home/hmslati/.local/lib/python3.6/site-packages/MDAnalysis/
#    from /home/hmslati/.local/lib/python3.6/site-packages/~DAnalysis
# ERROR: Command errored out with exit status 1: /groups/cherkasvgrp/share/progressive_docking/pd_python/tensorflow_gpu/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-0m66epng/mdanalysis_4f7b6334342a4203b56730aae7e1b584/package/setup.py'"'"'; __file__='"'"'/tmp/pip-install-0m66epng/mdanalysis_4f7b6334342a4203b56730aae7e1b584/package/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-uc6j8err/install-record.txt --single-version-externally-managed --user --prefix= --compile --install-headers /home/hmslati/.local/include/python3.6m/mdanalysis Check the logs for full command output.
# WARNING: You are using pip version 20.3.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/groups/cherkasvgrp/share/progressive_docking/pd_python/tensorflow_gpu/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
